# %%
# Import all the tools we need

# Regular EDA (exploratory data analysis) and plotting libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from numpy import mean
from numpy import std
# we want our plots to appear inside the notebook
# %matplotlib inline
from matplotlib.pyplot import figure
import json
import pickle
# Models from Scikit-Learn
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import validation_curve
# Model Evaluations
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.model_selection import RandomizedSearchCV, GridSearchCV
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.metrics import precision_score, recall_score, f1_score
from sklearn.metrics import plot_roc_curve
from sklearn.model_selection import RepeatedKFold
from sklearn.model_selection import cross_val_score
from sklearn.linear_model import LogisticRegression
import warnings
from sklearn.svm import SVC
from sklearn.model_selection import learning_curve #LearningCurveDisplay, ShuffleSplit

# %%
import pandas as pd
from sklearn.feature_selection import RFE
import numpy as np
from imblearn.over_sampling import SMOTE
import plotly.express as px
import plotly.graph_objects as go
from plotly.subplots import make_subplots
import scipy
from sklearn.preprocessing import MinMaxScaler
# %matplotlib inline
import matplotlib.pyplot as plt
from scipy.signal import detrend
import sys
import seaborn as sns
import sklearn
from mlxtend.plotting import plot_learning_curves
from sklearn import preprocessing
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn import metrics
from sklearn.metrics import confusion_matrix
from sklearn.metrics import precision_score, recall_score, f1_score, accuracy_score
from sklearn.datasets import make_classification
from matplotlib import pyplot
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import mean_squared_error
from sklearn.inspection import permutation_importance
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.preprocessing import StandardScaler
from torch import nn
from torch.nn import functional as F
from sklearn.metrics import roc_curve
from sklearn.ensemble import RandomForestClassifier
from sklearn.datasets import make_classification
import random
import scipy.stats as stats
import statsmodels.api as sm
from mlxtend.plotting import plot_learning_curves
from sklearn.model_selection import learning_curve
from scipy.cluster.hierarchy import linkage, dendrogram, fcluster
from scipy.spatial.distance import squareform
from sklearn.metrics import roc_auc_score

# %% [markdown]
# ## Load Data
#
# There are many different kinds of ways to store data. The typical way of storing **tabular data**, data similar to what you'd see in an Excel file is in .csv format. .csv stands for comma seperated values.
#
# Pandas has a built-in function to read .csv files called read_csv() which takes the file pathname of your .csv file. You'll likely use this a lot.

# %%
#Read
df= pd.read_csv('/Users/cyrilleetude/Desktop/BureauMacBookAirdeCyrille/Semester_Project_Cyrille_2022/MachineLEARNING/DATASET.csv')

#Clean
    #Drop irrelevant column
df.drop(df.columns[[0]], axis=1, inplace=True) #unnamed
 
    #Save column names
column_list = list(df.columns)

df.shape
# Out:
# (393, 47)

# %%
    # Check balance
        # Pre-Check
xx=df['Category Encoded (0 = Non Fallers | 1 = Fallers)'].value_counts().reset_index()
print('Before SMOTE : ', df.shape)
display(sns.barplot(x = "index", y = "Category Encoded (0 = Non Fallers | 1 = Fallers)", data=xx))
#         # SMOTE
#         #     Define features and target
# y= df.iloc[:,-1:]#target
# X = df.iloc[:,0:-1].values#MinMaxScaler().fit(df.iloc[:,0:-1]).transform(df.iloc[:,0:-1])#Scaled features
#             # Run SMOTE
# smote = SMOTE()
# X, y = smote.fit_resample(X, y)

# df = pd.concat([pd.DataFrame(X), y], axis=1)
#         # Re-Check
# xx_2=df['Category Encoded (0 = Non Fallers | 1 = Fallers)'].value_counts().reset_index()
# print('After SMOTE: ', df.shape)
# display(sns.barplot(x = "index", y = "Category Encoded (0 = Non Fallers | 1 = Fallers)", data=xx_2))
#         # relabel the columns
# df.columns = column_list

#         # re-binarize the column that need to stay binary
# df["Falls12m"] =  [float(np.round(i)) for i in df["Falls12m"].to_list()]
# df['Best_T'] = [float(np.round(i)) for i in df["Best_T"].to_list()]
# df['FES_T'] = [float(np.round(i)) for i in df["FES_T"].to_list()]
# df["AgeGroup(0=young|1=old)"] = [float(np.round(i)) for i in df["AgeGroup(0=young|1=old)"].to_list()]
# df["Gender(0=F|1=M)"] = [float(np.round(i)) for i in df["Gender(0=F|1=M)"].to_list()]
# df["IPAQ_S"] = [float(np.round(i)) for i in df["IPAQ_S"].to_list()]
# Out:
# Before SMOTE :  (393, 47)
# <AxesSubplot:xlabel='index', ylabel='Category Encoded (0 = Non Fallers | 1 = Fallers)'>

# %% [markdown]
# ### Correlation between independent variables
#
# Finally, we'll compare all of the independent variables in one hit.
#
# Why?
#
# Because this may give an idea of which independent variables may or may not have an impact on our target variable.
#
# We can do ths using `df.corr()` which will create a [correlation matrix](https://www.statisticshowto.com/correlation-matrix/) for us, in other words, a big table of numbers telling us how related each variable is to other.

# %%
# Find the correlation between our independent variables
corr_matrix = df.corr()
corr_matrix
# Out:
#                                                   Area (m^2)_fc  \
# Area (m^2)_fc                                          1.000000
# Range AP (m)_fc                                        0.827799
# Range ML (m)_fc                                        0.881258
# Sway Length AP (m)_fc                                  0.698024
# Sway Length ML (m)_fc                                  0.701586
# Mean Velocity AP (m/s)_fc                              0.698024
# Mean Velocity ML (m/s)_fc                              0.701586
# RMS Acc AP (g)_fc                                      0.544806
# RMS Acc ML (g)_fc                                      0.500679
# Area (m^2)_fo                                          0.159888
# Range AP (m)_fo                                        0.062968
# Range ML (m)_fo                                        0.218117
# Sway Length AP (m)_fo                                  0.133429
# Sway Length ML (m)_fo                                  0.189179
# Mean Velocity AP (m/s)_fo                              0.133429
# Mean Velocity ML (m/s)_fo                              0.189179
# RMS Acc AP (g)_fo                                      0.131337
# RMS Acc ML (g)_fo                                      0.146463
# Area (m^2)_gc                                          0.077516
# Range AP (m)_gc                                        0.050559
# Range ML (m)_gc                                        0.107608
# Sway Length AP (m)_gc                                  0.119412
# Sway Length ML (m)_gc                                  0.104146
# Mean Velocity AP (m/s)_gc                              0.119412
# Mean Velocity ML (m/s)_gc                              0.104146
# RMS Acc AP (g)_gc                                      0.080215
# RMS Acc ML (g)_gc                                      0.081643
# Area (m^2)_go                                          0.008248
# Range AP (m)_go                                       -0.001691
# Range ML (m)_go                                        0.049488
# Sway Length AP (m)_go                                  0.095531
# Sway Length ML (m)_go                                  0.101965
# Mean Velocity AP (m/s)_go                              0.095531
# Mean Velocity ML (m/s)_go                              0.101965
# RMS Acc AP (g)_go                                      0.109203
# RMS Acc ML (g)_go                                      0.133326
# Age                                                    0.165540
# Height                                                -0.078284
# Weight                                                -0.011519
# BMI                                                    0.050268
# Falls12m                                               0.395671
# Best_T                                                -0.170463
# FES_T                                                 -0.034320
# AgeGroup(0=young|1=old)                                0.175162
# Gender(0=F|1=M)                                       -0.025698
# IPAQ_S                                                -0.065725
# Category Encoded (0 = Non Fallers | 1 = Fallers)       0.424038
#
#                                                   Range AP (m)_fc  \
# Area (m^2)_fc                                            0.827799
# Range AP (m)_fc                                          1.000000
# Range ML (m)_fc                                          0.641899
# Sway Length AP (m)_fc                                    0.706526
# Sway Length ML (m)_fc                                    0.591558
# Mean Velocity AP (m/s)_fc                                0.706526
# Mean Velocity ML (m/s)_fc                                0.591558
# RMS Acc AP (g)_fc                                        0.511399
# RMS Acc ML (g)_fc                                        0.464619
# Area (m^2)_fo                                            0.130644
# Range AP (m)_fo                                          0.017194
# Range ML (m)_fo                                          0.187543
# Sway Length AP (m)_fo                                    0.080451
# Sway Length ML (m)_fo                                    0.130151
# Mean Velocity AP (m/s)_fo                                0.080451
# Mean Velocity ML (m/s)_fo                                0.130151
# RMS Acc AP (g)_fo                                        0.096547
# RMS Acc ML (g)_fo                                        0.107987
# Area (m^2)_gc                                            0.066347
# Range AP (m)_gc                                          0.016293
# Range ML (m)_gc                                          0.118401
# Sway Length AP (m)_gc                                    0.080926
# Sway Length ML (m)_gc                                    0.100215
# Mean Velocity AP (m/s)_gc                                0.080926
# Mean Velocity ML (m/s)_gc                                0.100215
# RMS Acc AP (g)_gc                                        0.043547
# RMS Acc ML (g)_gc                                        0.043754
# Area (m^2)_go                                            0.009720
# Range AP (m)_go                                         -0.006234
# Range ML (m)_go                                          0.045297
# Sway Length AP (m)_go                                    0.079393
# Sway Length ML (m)_go                                    0.106823
# Mean Velocity AP (m/s)_go                                0.079393
# Mean Velocity ML (m/s)_go                                0.106823
# RMS Acc AP (g)_go                                        0.109547
# RMS Acc ML (g)_go                                        0.137506
# Age                                                      0.107895
# Height                                                  -0.054047
# Weight                                                  -0.006951
# BMI                                                      0.033185
# Falls12m                                                 0.299281
# Best_T                                                  -0.137927
# FES_T                                                   -0.015455
# AgeGroup(0=young|1=old)                                  0.111573
# Gender(0=F|1=M)                                          0.001784
# IPAQ_S                                                  -0.033182
# Category Encoded (0 = Non Fallers | 1 = Fallers)         0.313434
#
#                                                   Range ML (m)_fc  \
# Area (m^2)_fc                                            0.881258
# Range AP (m)_fc                                          0.641899
# Range ML (m)_fc                                          1.000000
# Sway Length AP (m)_fc                                    0.673920
# Sway Length ML (m)_fc                                    0.755233
# Mean Velocity AP (m/s)_fc                                0.673920
# Mean Velocity ML (m/s)_fc                                0.755233
# RMS Acc AP (g)_fc                                        0.578208
# RMS Acc ML (g)_fc                                        0.558522
# Area (m^2)_fo                                            0.169716
# Range AP (m)_fo                                          0.083834
# Range ML (m)_fo                                          0.234388
# Sway Length AP (m)_fo                                    0.148615
# Sway Length ML (m)_fo                                    0.206814
# Mean Velocity AP (m/s)_fo                                0.148615
# Mean Velocity ML (m/s)_fo                                0.206814
# RMS Acc AP (g)_fo                                        0.132851
# RMS Acc ML (g)_fo                                        0.139981
# Area (m^2)_gc                                            0.049511
# Range AP (m)_gc                                          0.071200
# Range ML (m)_gc                                          0.061505
# Sway Length AP (m)_gc                                    0.124282
# Sway Length ML (m)_gc                                    0.078075
# Mean Velocity AP (m/s)_gc                                0.124282
# Mean Velocity ML (m/s)_gc                                0.078075
# RMS Acc AP (g)_gc                                        0.103489
# RMS Acc ML (g)_gc                                        0.100497
# Area (m^2)_go                                           -0.004696
# Range AP (m)_go                                          0.011319
# Range ML (m)_go                                          0.015905
# Sway Length AP (m)_go                                    0.033004
# Sway Length ML (m)_go                                    0.036019
# Mean Velocity AP (m/s)_go                                0.033004
# Mean Velocity ML (m/s)_go                                0.036019
# RMS Acc AP (g)_go                                        0.027350
# RMS Acc ML (g)_go                                        0.064323
# Age                                                      0.164264
# Height                                                  -0.055942
# Weight                                                   0.009962
# BMI                                                      0.047875
# Falls12m                                                 0.372245
# Best_T                                                  -0.156822
# FES_T                                                   -0.054320
# AgeGroup(0=young|1=old)                                  0.174857
# Gender(0=F|1=M)                                          0.002241
# IPAQ_S                                                  -0.044239
# Category Encoded (0 = Non Fallers | 1 = Fallers)         0.398020
#
#                                                   Sway Length AP (m)_fc  \
# Area (m^2)_fc                                                  0.698024
# Range AP (m)_fc                                                0.706526
# Range ML (m)_fc                                                0.673920
# Sway Length AP (m)_fc                                          1.000000
# Sway Length ML (m)_fc                                          0.754442
# Mean Velocity AP (m/s)_fc                                      1.000000
# Mean Velocity ML (m/s)_fc                                      0.754442
# RMS Acc AP (g)_fc                                              0.892303
# RMS Acc ML (g)_fc                                              0.684314
# Area (m^2)_fo                                                  0.130951
# Range AP (m)_fo                                                0.025945
# Range ML (m)_fo                                                0.185994
# Sway Length AP (m)_fo                                          0.078696
# Sway Length ML (m)_fo                                          0.141744
# Mean Velocity AP (m/s)_fo                                      0.078696
# Mean Velocity ML (m/s)_fo                                      0.141744
# RMS Acc AP (g)_fo                                              0.057522
# RMS Acc ML (g)_fo                                              0.086762
# Area (m^2)_gc                                                  0.082071
# Range AP (m)_gc                                                0.060050
# Range ML (m)_gc                                                0.116670
# Sway Length AP (m)_gc                                          0.147325
# Sway Length ML (m)_gc                                          0.115545
# Mean Velocity AP (m/s)_gc                                      0.147325
# Mean Velocity ML (m/s)_gc                                      0.115545
# RMS Acc AP (g)_gc                                              0.125710
# RMS Acc ML (g)_gc                                              0.116542
# Area (m^2)_go                                                  0.009866
# Range AP (m)_go                                               -0.005032
# Range ML (m)_go                                                0.029281
# Sway Length AP (m)_go                                          0.005623
# Sway Length ML (m)_go                                          0.039692
# Mean Velocity AP (m/s)_go                                      0.005623
# Mean Velocity ML (m/s)_go                                      0.039692
# RMS Acc AP (g)_go                                              0.005646
# RMS Acc ML (g)_go                                              0.055647
# Age                                                            0.093949
# Height                                                        -0.059205
# Weight                                                         0.014626
# BMI                                                            0.054264
# Falls12m                                                       0.278392
# Best_T                                                        -0.099496
# FES_T                                                         -0.023479
# AgeGroup(0=young|1=old)                                        0.099090
# Gender(0=F|1=M)                                               -0.036671
# IPAQ_S                                                        -0.045751
# Category Encoded (0 = Non Fallers | 1 = Fallers)               0.294696
#
#                                                   Sway Length ML (m)_fc  \
# Area (m^2)_fc                                                  0.701586
# Range AP (m)_fc                                                0.591558
# Range ML (m)_fc                                                0.755233
# Sway Length AP (m)_fc                                          0.754442
# Sway Length ML (m)_fc                                          1.000000
# Mean Velocity AP (m/s)_fc                                      0.754442
# Mean Velocity ML (m/s)_fc                                      1.000000
# RMS Acc AP (g)_fc                                              0.702300
# RMS Acc ML (g)_fc                                              0.890901
# Area (m^2)_fo                                                  0.128943
# Range AP (m)_fo                                                0.054751
# Range ML (m)_fo                                                0.156609
# Sway Length AP (m)_fo                                          0.108055
# Sway Length ML (m)_fo                                          0.154184
# Mean Velocity AP (m/s)_fo                                      0.108055
# Mean Velocity ML (m/s)_fo                                      0.154184
# RMS Acc AP (g)_fo                                              0.076884
# RMS Acc ML (g)_fo                                              0.085909
# Area (m^2)_gc                                                  0.066667
# Range AP (m)_gc                                                0.009442
# Range ML (m)_gc                                                0.105225
# Sway Length AP (m)_gc                                          0.100176
# Sway Length ML (m)_gc                                          0.096840
# Mean Velocity AP (m/s)_gc                                      0.100176
# Mean Velocity ML (m/s)_gc                                      0.096840
# RMS Acc AP (g)_gc                                              0.103715
# RMS Acc ML (g)_gc                                              0.102670
# Area (m^2)_go                                                 -0.054905
# Range AP (m)_go                                               -0.059049
# Range ML (m)_go                                               -0.006885
# Sway Length AP (m)_go                                          0.008145
# Sway Length ML (m)_go                                         -0.003178
# Mean Velocity AP (m/s)_go                                      0.008145
# Mean Velocity ML (m/s)_go                                     -0.003178
# RMS Acc AP (g)_go                                              0.038849
# RMS Acc ML (g)_go                                              0.025000
# Age                                                            0.096991
# Height                                                        -0.053301
# Weight                                                        -0.006294
# BMI                                                            0.031581
# Falls12m                                                       0.218137
# Best_T                                                        -0.092155
# FES_T                                                         -0.042372
# AgeGroup(0=young|1=old)                                        0.110196
# Gender(0=F|1=M)                                                0.018273
# IPAQ_S                                                        -0.082497
# Category Encoded (0 = Non Fallers | 1 = Fallers)               0.251151
#
#                                                   Mean Velocity AP (m/s)_fc  \
# Area (m^2)_fc                                                      0.698024
# Range AP (m)_fc                                                    0.706526
# Range ML (m)_fc                                                    0.673920
# Sway Length AP (m)_fc                                              1.000000
# Sway Length ML (m)_fc                                              0.754442
# Mean Velocity AP (m/s)_fc                                          1.000000
# Mean Velocity ML (m/s)_fc                                          0.754442
# RMS Acc AP (g)_fc                                                  0.892303
# RMS Acc ML (g)_fc                                                  0.684314
# Area (m^2)_fo                                                      0.130951
# Range AP (m)_fo                                                    0.025945
# Range ML (m)_fo                                                    0.185994
# Sway Length AP (m)_fo                                              0.078696
# Sway Length ML (m)_fo                                              0.141744
# Mean Velocity AP (m/s)_fo                                          0.078696
# Mean Velocity ML (m/s)_fo                                          0.141744
# RMS Acc AP (g)_fo                                                  0.057522
# RMS Acc ML (g)_fo                                                  0.086762
# Area (m^2)_gc                                                      0.082071
# Range AP (m)_gc                                                    0.060050
# Range ML (m)_gc                                                    0.116670
# Sway Length AP (m)_gc                                              0.147325
# Sway Length ML (m)_gc                                              0.115545
# Mean Velocity AP (m/s)_gc                                          0.147325
# Mean Velocity ML (m/s)_gc                                          0.115545
# RMS Acc AP (g)_gc                                                  0.125710
# RMS Acc ML (g)_gc                                                  0.116542
# Area (m^2)_go                                                      0.009866
# Range AP (m)_go                                                   -0.005032
# Range ML (m)_go                                                    0.029281
# Sway Length AP (m)_go                                              0.005623
# Sway Length ML (m)_go                                              0.039692
# Mean Velocity AP (m/s)_go                                          0.005623
# Mean Velocity ML (m/s)_go                                          0.039692
# RMS Acc AP (g)_go                                                  0.005646
# RMS Acc ML (g)_go                                                  0.055647
# Age                                                                0.093949
# Height                                                            -0.059205
# Weight                                                             0.014626
# BMI                                                                0.054264
# Falls12m                                                           0.278392
# Best_T                                                            -0.099496
# FES_T                                                             -0.023479
# AgeGroup(0=young|1=old)                                            0.099090
# Gender(0=F|1=M)                                                   -0.036671
# IPAQ_S                                                            -0.045751
# Category Encoded (0 = Non Fallers | 1 = Fallers)                   0.294696
#
#                                                   Mean Velocity ML (m/s)_fc  \
# Area (m^2)_fc                                                      0.701586
# Range AP (m)_fc                                                    0.591558
# Range ML (m)_fc                                                    0.755233
# Sway Length AP (m)_fc                                              0.754442
# Sway Length ML (m)_fc                                              1.000000
# Mean Velocity AP (m/s)_fc                                          0.754442
# Mean Velocity ML (m/s)_fc                                          1.000000
# RMS Acc AP (g)_fc                                                  0.702300
# RMS Acc ML (g)_fc                                                  0.890901
# Area (m^2)_fo                                                      0.128943
# Range AP (m)_fo                                                    0.054751
# Range ML (m)_fo                                                    0.156609
# Sway Length AP (m)_fo                                              0.108055
# Sway Length ML (m)_fo                                              0.154184
# Mean Velocity AP (m/s)_fo                                          0.108055
# Mean Velocity ML (m/s)_fo                                          0.154184
# RMS Acc AP (g)_fo                                                  0.076884
# RMS Acc ML (g)_fo                                                  0.085909
# Area (m^2)_gc                                                      0.066667
# Range AP (m)_gc                                                    0.009442
# Range ML (m)_gc                                                    0.105225
# Sway Length AP (m)_gc                                              0.100176
# Sway Length ML (m)_gc                                              0.096840
# Mean Velocity AP (m/s)_gc                                          0.100176
# Mean Velocity ML (m/s)_gc                                          0.096840
# RMS Acc AP (g)_gc                                                  0.103715
# RMS Acc ML (g)_gc                                                  0.102670
# Area (m^2)_go                                                     -0.054905
# Range AP (m)_go                                                   -0.059049
# Range ML (m)_go                                                   -0.006885
# Sway Length AP (m)_go                                              0.008145
# Sway Length ML (m)_go                                             -0.003178
# Mean Velocity AP (m/s)_go                                          0.008145
# Mean Velocity ML (m/s)_go                                         -0.003178
# RMS Acc AP (g)_go                                                  0.038849
# RMS Acc ML (g)_go                                                  0.025000
# Age                                                                0.096991
# Height                                                            -0.053301
# Weight                                                            -0.006294
# BMI                                                                0.031581
# Falls12m                                                           0.218137
# Best_T                                                            -0.092155
# FES_T                                                             -0.042372
# AgeGroup(0=young|1=old)                                            0.110196
# Gender(0=F|1=M)                                                    0.018273
# IPAQ_S                                                            -0.082497
# Category Encoded (0 = Non Fallers | 1 = Fallers)                   0.251151
#
#                                                   RMS Acc AP (g)_fc  \
# Area (m^2)_fc                                              0.544806
# Range AP (m)_fc                                            0.511399
# Range ML (m)_fc                                            0.578208
# Sway Length AP (m)_fc                                      0.892303
# Sway Length ML (m)_fc                                      0.702300
# Mean Velocity AP (m/s)_fc                                  0.892303
# Mean Velocity ML (m/s)_fc                                  0.702300
# RMS Acc AP (g)_fc                                          1.000000
# RMS Acc ML (g)_fc                                          0.695344
# Area (m^2)_fo                                              0.158022
# Range AP (m)_fo                                            0.060001
# Range ML (m)_fo                                            0.200916
# Sway Length AP (m)_fo                                      0.118921
# Sway Length ML (m)_fo                                      0.180905
# Mean Velocity AP (m/s)_fo                                  0.118921
# Mean Velocity ML (m/s)_fo                                  0.180905
# RMS Acc AP (g)_fo                                          0.090863
# RMS Acc ML (g)_fo                                          0.112661
# Area (m^2)_gc                                              0.051882
# Range AP (m)_gc                                            0.061965
# Range ML (m)_gc                                            0.082930
# Sway Length AP (m)_gc                                      0.148207
# Sway Length ML (m)_gc                                      0.073319
# Mean Velocity AP (m/s)_gc                                  0.148207
# Mean Velocity ML (m/s)_gc                                  0.073319
# RMS Acc AP (g)_gc                                          0.129797
# RMS Acc ML (g)_gc                                          0.092810
# Area (m^2)_go                                              0.002488
# Range AP (m)_go                                            0.017755
# Range ML (m)_go                                            0.017705
# Sway Length AP (m)_go                                     -0.032846
# Sway Length ML (m)_go                                      0.000459
# Mean Velocity AP (m/s)_go                                 -0.032846
# Mean Velocity ML (m/s)_go                                  0.000459
# RMS Acc AP (g)_go                                         -0.037433
# RMS Acc ML (g)_go                                          0.018341
# Age                                                        0.106319
# Height                                                    -0.076271
# Weight                                                     0.026195
# BMI                                                        0.081979
# Falls12m                                                   0.232282
# Best_T                                                    -0.100917
# FES_T                                                     -0.033775
# AgeGroup(0=young|1=old)                                    0.120857
# Gender(0=F|1=M)                                           -0.032878
# IPAQ_S                                                    -0.051074
# Category Encoded (0 = Non Fallers | 1 = Fallers)           0.247307
#
#                                                   RMS Acc ML (g)_fc  \
# Area (m^2)_fc                                              0.500679
# Range AP (m)_fc                                            0.464619
# Range ML (m)_fc                                            0.558522
# Sway Length AP (m)_fc                                      0.684314
# Sway Length ML (m)_fc                                      0.890901
# Mean Velocity AP (m/s)_fc                                  0.684314
# Mean Velocity ML (m/s)_fc                                  0.890901
# RMS Acc AP (g)_fc                                          0.695344
# RMS Acc ML (g)_fc                                          1.000000
# Area (m^2)_fo                                              0.089179
# Range AP (m)_fo                                            0.027436
# Range ML (m)_fo                                            0.080687
# Sway Length AP (m)_fo                                      0.084457
# Sway Length ML (m)_fo                                      0.097153
# Mean Velocity AP (m/s)_fo                                  0.084457
# Mean Velocity ML (m/s)_fo                                  0.097153
# RMS Acc AP (g)_fo                                          0.052133
# RMS Acc ML (g)_fo                                          0.045015
# Area (m^2)_gc                                              0.026384
# Range AP (m)_gc                                           -0.002732
# Range ML (m)_gc                                            0.077397
# Sway Length AP (m)_gc                                      0.082447
# Sway Length ML (m)_gc                                      0.064479
# Mean Velocity AP (m/s)_gc                                  0.082447
# Mean Velocity ML (m/s)_gc                                  0.064479
# RMS Acc AP (g)_gc                                          0.099936
# RMS Acc ML (g)_gc                                          0.085242
# Area (m^2)_go                                             -0.041738
# Range AP (m)_go                                           -0.040703
# Range ML (m)_go                                            0.014452
# Sway Length AP (m)_go                                      0.003005
# Sway Length ML (m)_go                                      0.010220
# Mean Velocity AP (m/s)_go                                  0.003005
# Mean Velocity ML (m/s)_go                                  0.010220
# RMS Acc AP (g)_go                                          0.034259
# RMS Acc ML (g)_go                                          0.032541
# Age                                                        0.078873
# Height                                                    -0.056700
# Weight                                                     0.023313
# BMI                                                        0.067172
# Falls12m                                                   0.133432
# Best_T                                                    -0.061952
# FES_T                                                     -0.050673
# AgeGroup(0=young|1=old)                                    0.088289
# Gender(0=F|1=M)                                            0.002413
# IPAQ_S                                                    -0.093581
# Category Encoded (0 = Non Fallers | 1 = Fallers)           0.162889
#
#                                                   Area (m^2)_fo  ...  \
# Area (m^2)_fc                                          0.159888  ...
# Range AP (m)_fc                                        0.130644  ...
# Range ML (m)_fc                                        0.169716  ...
# Sway Length AP (m)_fc                                  0.130951  ...
# Sway Length ML (m)_fc                                  0.128943  ...
# Mean Velocity AP (m/s)_fc                              0.130951  ...
# Mean Velocity ML (m/s)_fc                              0.128943  ...
# RMS Acc AP (g)_fc                                      0.158022  ...
# RMS Acc ML (g)_fc                                      0.089179  ...
# Area (m^2)_fo                                          1.000000  ...
# Range AP (m)_fo                                        0.792849  ...
# Range ML (m)_fo                                        0.827289  ...
# Sway Length AP (m)_fo                                  0.638624  ...
# Sway Length ML (m)_fo                                  0.700435  ...
# Mean Velocity AP (m/s)_fo                              0.638624  ...
# Mean Velocity ML (m/s)_fo                              0.700435  ...
# RMS Acc AP (g)_fo                                      0.495908  ...
# RMS Acc ML (g)_fo                                      0.493900  ...
# Area (m^2)_gc                                          0.036039  ...
# Range AP (m)_gc                                        0.030105  ...
# Range ML (m)_gc                                        0.045763  ...
# Sway Length AP (m)_gc                                  0.113719  ...
# Sway Length ML (m)_gc                                  0.077490  ...
# Mean Velocity AP (m/s)_gc                              0.113719  ...
# Mean Velocity ML (m/s)_gc                              0.077490  ...
# RMS Acc AP (g)_gc                                      0.107979  ...
# RMS Acc ML (g)_gc                                      0.048613  ...
# Area (m^2)_go                                          0.012846  ...
# Range AP (m)_go                                        0.064750  ...
# Range ML (m)_go                                        0.003179  ...
# Sway Length AP (m)_go                                  0.105509  ...
# Sway Length ML (m)_go                                  0.054900  ...
# Mean Velocity AP (m/s)_go                              0.105509  ...
# Mean Velocity ML (m/s)_go                              0.054900  ...
# RMS Acc AP (g)_go                                      0.122730  ...
# RMS Acc ML (g)_go                                      0.098471  ...
# Age                                                    0.078354  ...
# Height                                                -0.103152  ...
# Weight                                                -0.063341  ...
# BMI                                                    0.027614  ...
# Falls12m                                               0.361961  ...
# Best_T                                                -0.098732  ...
# FES_T                                                 -0.017995  ...
# AgeGroup(0=young|1=old)                                0.097620  ...
# Gender(0=F|1=M)                                       -0.085906  ...
# IPAQ_S                                                -0.065371  ...
# Category Encoded (0 = Non Fallers | 1 = Fallers)       0.366445  ...
#
#                                                     Height    Weight  \
# Area (m^2)_fc                                    -0.078284 -0.011519
# Range AP (m)_fc                                  -0.054047 -0.006951
# Range ML (m)_fc                                  -0.055942  0.009962
# Sway Length AP (m)_fc                            -0.059205  0.014626
# Sway Length ML (m)_fc                            -0.053301 -0.006294
# Mean Velocity AP (m/s)_fc                        -0.059205  0.014626
# Mean Velocity ML (m/s)_fc                        -0.053301 -0.006294
# RMS Acc AP (g)_fc                                -0.076271  0.026195
# RMS Acc ML (g)_fc                                -0.056700  0.023313
# Area (m^2)_fo                                    -0.103152 -0.063341
# Range AP (m)_fo                                  -0.057989 -0.038538
# Range ML (m)_fo                                  -0.082168 -0.027087
# Sway Length AP (m)_fo                            -0.108181 -0.058339
# Sway Length ML (m)_fo                            -0.093455 -0.021362
# Mean Velocity AP (m/s)_fo                        -0.108181 -0.058339
# Mean Velocity ML (m/s)_fo                        -0.093455 -0.021362
# RMS Acc AP (g)_fo                                -0.073042 -0.039660
# RMS Acc ML (g)_fo                                -0.088151 -0.029646
# Area (m^2)_gc                                    -0.064375 -0.041617
# Range AP (m)_gc                                   0.000611 -0.004796
# Range ML (m)_gc                                  -0.086841 -0.082419
# Sway Length AP (m)_gc                            -0.041670 -0.028906
# Sway Length ML (m)_gc                            -0.096916 -0.064116
# Mean Velocity AP (m/s)_gc                        -0.041670 -0.028906
# Mean Velocity ML (m/s)_gc                        -0.096916 -0.064116
# RMS Acc AP (g)_gc                                -0.033611 -0.007980
# RMS Acc ML (g)_gc                                -0.054335 -0.012319
# Area (m^2)_go                                    -0.003697 -0.097006
# Range AP (m)_go                                  -0.006351 -0.071388
# Range ML (m)_go                                  -0.024416 -0.069272
# Sway Length AP (m)_go                            -0.014450 -0.113343
# Sway Length ML (m)_go                            -0.035754 -0.096164
# Mean Velocity AP (m/s)_go                        -0.014450 -0.113343
# Mean Velocity ML (m/s)_go                        -0.035754 -0.096164
# RMS Acc AP (g)_go                                -0.027427 -0.069824
# RMS Acc ML (g)_go                                -0.041376 -0.091737
# Age                                              -0.554644  0.013482
# Height                                            1.000000  0.418617
# Weight                                            0.418617  1.000000
# BMI                                              -0.493696  0.576926
# Falls12m                                         -0.172115 -0.016171
# Best_T                                            0.501411  0.111715
# FES_T                                            -0.039638 -0.041214
# AgeGroup(0=young|1=old)                          -0.512361  0.047023
# Gender(0=F|1=M)                                   0.660848  0.369667
# IPAQ_S                                           -0.172411 -0.054376
# Category Encoded (0 = Non Fallers | 1 = Fallers) -0.182043 -0.042460
#
#                                                        BMI  Falls12m  \
# Area (m^2)_fc                                     0.050268  0.395671
# Range AP (m)_fc                                   0.033185  0.299281
# Range ML (m)_fc                                   0.047875  0.372245
# Sway Length AP (m)_fc                             0.054264  0.278392
# Sway Length ML (m)_fc                             0.031581  0.218137
# Mean Velocity AP (m/s)_fc                         0.054264  0.278392
# Mean Velocity ML (m/s)_fc                         0.031581  0.218137
# RMS Acc AP (g)_fc                                 0.081979  0.232282
# RMS Acc ML (g)_fc                                 0.067172  0.133432
# Area (m^2)_fo                                     0.027614  0.361961
# Range AP (m)_fo                                   0.014445  0.219261
# Range ML (m)_fo                                   0.037938  0.356712
# Sway Length AP (m)_fo                             0.032302  0.341620
# Sway Length ML (m)_fo                             0.055242  0.310030
# Mean Velocity AP (m/s)_fo                         0.032302  0.341620
# Mean Velocity ML (m/s)_fo                         0.055242  0.310030
# RMS Acc AP (g)_fo                                 0.016089  0.308070
# RMS Acc ML (g)_fo                                 0.041155  0.238157
# Area (m^2)_gc                                     0.011994  0.072606
# Range AP (m)_gc                                  -0.010226  0.125264
# Range ML (m)_gc                                  -0.006719  0.077512
# Sway Length AP (m)_gc                             0.005595  0.214669
# Sway Length ML (m)_gc                             0.021323  0.156595
# Mean Velocity AP (m/s)_gc                         0.005595  0.214669
# Mean Velocity ML (m/s)_gc                         0.021323  0.156595
# RMS Acc AP (g)_gc                                 0.020447  0.204218
# RMS Acc ML (g)_gc                                 0.033914  0.156130
# Area (m^2)_go                                    -0.088553  0.142289
# Range AP (m)_go                                  -0.065393  0.179416
# Range ML (m)_go                                  -0.047255  0.113141
# Sway Length AP (m)_go                            -0.095449  0.262579
# Sway Length ML (m)_go                            -0.062350  0.162450
# Mean Velocity AP (m/s)_go                        -0.095449  0.262579
# Mean Velocity ML (m/s)_go                        -0.062350  0.162450
# RMS Acc AP (g)_go                                -0.044900  0.213814
# RMS Acc ML (g)_go                                -0.052975  0.138851
# Age                                               0.504058  0.279309
# Height                                           -0.493696 -0.172115
# Weight                                            0.576926 -0.016171
# BMI                                               1.000000  0.131984
# Falls12m                                          0.131984  1.000000
# Best_T                                           -0.346979 -0.308709
# FES_T                                             0.000377 -0.085779
# AgeGroup(0=young|1=old)                           0.498014  0.299808
# Gender(0=F|1=M)                                  -0.251336 -0.148118
# IPAQ_S                                            0.100155 -0.070321
# Category Encoded (0 = Non Fallers | 1 = Fallers)  0.114683  0.965991
#
#                                                     Best_T     FES_T  \
# Area (m^2)_fc                                    -0.170463 -0.034320
# Range AP (m)_fc                                  -0.137927 -0.015455
# Range ML (m)_fc                                  -0.156822 -0.054320
# Sway Length AP (m)_fc                            -0.099496 -0.023479
# Sway Length ML (m)_fc                            -0.092155 -0.042372
# Mean Velocity AP (m/s)_fc                        -0.099496 -0.023479
# Mean Velocity ML (m/s)_fc                        -0.092155 -0.042372
# RMS Acc AP (g)_fc                                -0.100917 -0.033775
# RMS Acc ML (g)_fc                                -0.061952 -0.050673
# Area (m^2)_fo                                    -0.098732 -0.017995
# Range AP (m)_fo                                  -0.055253  0.007969
# Range ML (m)_fo                                  -0.152060 -0.014984
# Sway Length AP (m)_fo                            -0.163868 -0.045515
# Sway Length ML (m)_fo                            -0.163245 -0.065462
# Mean Velocity AP (m/s)_fo                        -0.163868 -0.045515
# Mean Velocity ML (m/s)_fo                        -0.163245 -0.065462
# RMS Acc AP (g)_fo                                -0.168449 -0.030720
# RMS Acc ML (g)_fo                                -0.140139 -0.062446
# Area (m^2)_gc                                    -0.051669  0.008976
# Range AP (m)_gc                                   0.018678 -0.041040
# Range ML (m)_gc                                  -0.068234  0.013490
# Sway Length AP (m)_gc                            -0.018606 -0.018087
# Sway Length ML (m)_gc                            -0.033665 -0.023914
# Mean Velocity AP (m/s)_gc                        -0.018606 -0.018087
# Mean Velocity ML (m/s)_gc                        -0.033665 -0.023914
# RMS Acc AP (g)_gc                                -0.026608 -0.013092
# RMS Acc ML (g)_gc                                -0.000032 -0.028612
# Area (m^2)_go                                    -0.048384  0.014571
# Range AP (m)_go                                  -0.047362  0.034046
# Range ML (m)_go                                  -0.070640  0.072742
# Sway Length AP (m)_go                            -0.076670 -0.022507
# Sway Length ML (m)_go                            -0.055369  0.039634
# Mean Velocity AP (m/s)_go                        -0.076670 -0.022507
# Mean Velocity ML (m/s)_go                        -0.055369  0.039634
# RMS Acc AP (g)_go                                -0.057610 -0.049282
# RMS Acc ML (g)_go                                -0.038058 -0.001202
# Age                                              -0.752721 -0.112958
# Height                                            0.501411 -0.039638
# Weight                                            0.111715 -0.041214
# BMI                                              -0.346979  0.000377
# Falls12m                                         -0.308709 -0.085779
# Best_T                                            1.000000 -0.042584
# FES_T                                            -0.042584  1.000000
# AgeGroup(0=young|1=old)                          -0.702670 -0.065525
# Gender(0=F|1=M)                                   0.265998 -0.150560
# IPAQ_S                                           -0.138076 -0.050490
# Category Encoded (0 = Non Fallers | 1 = Fallers) -0.311518 -0.067670
#
#                                                   AgeGroup(0=young|1=old)  \
# Area (m^2)_fc                                                    0.175162
# Range AP (m)_fc                                                  0.111573
# Range ML (m)_fc                                                  0.174857
# Sway Length AP (m)_fc                                            0.099090
# Sway Length ML (m)_fc                                            0.110196
# Mean Velocity AP (m/s)_fc                                        0.099090
# Mean Velocity ML (m/s)_fc                                        0.110196
# RMS Acc AP (g)_fc                                                0.120857
# RMS Acc ML (g)_fc                                                0.088289
# Area (m^2)_fo                                                    0.097620
# Range AP (m)_fo                                                  0.055711
# Range ML (m)_fo                                                  0.124360
# Sway Length AP (m)_fo                                            0.186022
# Sway Length ML (m)_fo                                            0.151104
# Mean Velocity AP (m/s)_fo                                        0.186022
# Mean Velocity ML (m/s)_fo                                        0.151104
# RMS Acc AP (g)_fo                                                0.190456
# RMS Acc ML (g)_fo                                                0.131648
# Area (m^2)_gc                                                    0.117672
# Range AP (m)_gc                                                  0.066356
# Range ML (m)_gc                                                  0.110948
# Sway Length AP (m)_gc                                            0.066354
# Sway Length ML (m)_gc                                            0.100306
# Mean Velocity AP (m/s)_gc                                        0.066354
# Mean Velocity ML (m/s)_gc                                        0.100306
# RMS Acc AP (g)_gc                                                0.048075
# RMS Acc ML (g)_gc                                                0.079654
# Area (m^2)_go                                                   -0.008817
# Range AP (m)_go                                                 -0.004318
# Range ML (m)_go                                                  0.038388
# Sway Length AP (m)_go                                            0.025088
# Sway Length ML (m)_go                                            0.028678
# Mean Velocity AP (m/s)_go                                        0.025088
# Mean Velocity ML (m/s)_go                                        0.028678
# RMS Acc AP (g)_go                                                0.030152
# RMS Acc ML (g)_go                                                0.021512
# Age                                                              0.954594
# Height                                                          -0.512361
# Weight                                                           0.047023
# BMI                                                              0.498014
# Falls12m                                                         0.299808
# Best_T                                                          -0.702670
# FES_T                                                           -0.065525
# AgeGroup(0=young|1=old)                                          1.000000
# Gender(0=F|1=M)                                                 -0.198602
# IPAQ_S                                                           0.244896
# Category Encoded (0 = Non Fallers | 1 = Fallers)                 0.310363
#
#                                                   Gender(0=F|1=M)    IPAQ_S  \
# Area (m^2)_fc                                           -0.025698 -0.065725
# Range AP (m)_fc                                          0.001784 -0.033182
# Range ML (m)_fc                                          0.002241 -0.044239
# Sway Length AP (m)_fc                                   -0.036671 -0.045751
# Sway Length ML (m)_fc                                    0.018273 -0.082497
# Mean Velocity AP (m/s)_fc                               -0.036671 -0.045751
# Mean Velocity ML (m/s)_fc                                0.018273 -0.082497
# RMS Acc AP (g)_fc                                       -0.032878 -0.051074
# RMS Acc ML (g)_fc                                        0.002413 -0.093581
# Area (m^2)_fo                                           -0.085906 -0.065371
# Range AP (m)_fo                                         -0.109554 -0.093385
# Range ML (m)_fo                                         -0.053295 -0.072611
# Sway Length AP (m)_fo                                   -0.077371 -0.065002
# Sway Length ML (m)_fo                                   -0.053599 -0.060651
# Mean Velocity AP (m/s)_fo                               -0.077371 -0.065002
# Mean Velocity ML (m/s)_fo                               -0.053599 -0.060651
# RMS Acc AP (g)_fo                                       -0.030236 -0.052346
# RMS Acc ML (g)_fo                                       -0.062471 -0.082476
# Area (m^2)_gc                                           -0.021359  0.035594
# Range AP (m)_gc                                          0.039104  0.050031
# Range ML (m)_gc                                         -0.043356 -0.000974
# Sway Length AP (m)_gc                                   -0.036975  0.048350
# Sway Length ML (m)_gc                                   -0.063465 -0.009888
# Mean Velocity AP (m/s)_gc                               -0.036975  0.048350
# Mean Velocity ML (m/s)_gc                               -0.063465 -0.009888
# RMS Acc AP (g)_gc                                       -0.054942  0.028588
# RMS Acc ML (g)_gc                                       -0.068140 -0.037797
# Area (m^2)_go                                           -0.054025 -0.027229
# Range AP (m)_go                                         -0.022738 -0.047812
# Range ML (m)_go                                         -0.073790  0.033929
# Sway Length AP (m)_go                                    0.020409 -0.046797
# Sway Length ML (m)_go                                   -0.044011  0.015828
# Mean Velocity AP (m/s)_go                                0.020409 -0.046797
# Mean Velocity ML (m/s)_go                               -0.044011  0.015828
# RMS Acc AP (g)_go                                        0.037953 -0.041122
# RMS Acc ML (g)_go                                       -0.009846 -0.009979
# Age                                                     -0.208641  0.246933
# Height                                                   0.660848 -0.172411
# Weight                                                   0.369667 -0.054376
# BMI                                                     -0.251336  0.100155
# Falls12m                                                -0.148118 -0.070321
# Best_T                                                   0.265998 -0.138076
# FES_T                                                   -0.150560 -0.050490
# AgeGroup(0=young|1=old)                                 -0.198602  0.244896
# Gender(0=F|1=M)                                          1.000000 -0.080890
# IPAQ_S                                                  -0.080890  1.000000
# Category Encoded (0 = Non Fallers | 1 = Fallers)        -0.148881 -0.108919
#
#                                                   Category Encoded (0 = Non Fallers | 1 = Fallers)
# Area (m^2)_fc                                                                             0.424038
# Range AP (m)_fc                                                                           0.313434
# Range ML (m)_fc                                                                           0.398020
# Sway Length AP (m)_fc                                                                     0.294696
# Sway Length ML (m)_fc                                                                     0.251151
# Mean Velocity AP (m/s)_fc                                                                 0.294696
# Mean Velocity ML (m/s)_fc                                                                 0.251151
# RMS Acc AP (g)_fc                                                                         0.247307
# RMS Acc ML (g)_fc                                                                         0.162889
# Area (m^2)_fo                                                                             0.366445
# Range AP (m)_fo                                                                           0.219163
# Range ML (m)_fo                                                                           0.371661
# Sway Length AP (m)_fo                                                                     0.358558
# Sway Length ML (m)_fo                                                                     0.317054
# Mean Velocity AP (m/s)_fo                                                                 0.358558
# Mean Velocity ML (m/s)_fo                                                                 0.317054
# RMS Acc AP (g)_fo                                                                         0.332255
# RMS Acc ML (g)_fo                                                                         0.252304
# Area (m^2)_gc                                                                             0.073342
# Range AP (m)_gc                                                                           0.129772
# Range ML (m)_gc                                                                           0.078324
# Sway Length AP (m)_gc                                                                     0.228210
# Sway Length ML (m)_gc                                                                     0.148335
# Mean Velocity AP (m/s)_gc                                                                 0.228210
# Mean Velocity ML (m/s)_gc                                                                 0.148335
# RMS Acc AP (g)_gc                                                                         0.215559
# RMS Acc ML (g)_gc                                                                         0.152324
# Area (m^2)_go                                                                             0.153489
# Range AP (m)_go                                                                           0.181640
# Range ML (m)_go                                                                           0.130446
# Sway Length AP (m)_go                                                                     0.289488
# Sway Length ML (m)_go                                                                     0.191724
# Mean Velocity AP (m/s)_go                                                                 0.289488
# Mean Velocity ML (m/s)_go                                                                 0.191724
# RMS Acc AP (g)_go                                                                         0.235324
# RMS Acc ML (g)_go                                                                         0.168660
# Age                                                                                       0.291488
# Height                                                                                   -0.182043
# Weight                                                                                   -0.042460
# BMI                                                                                       0.114683
# Falls12m                                                                                  0.965991
# Best_T                                                                                   -0.311518
# FES_T                                                                                    -0.067670
# AgeGroup(0=young|1=old)                                                                   0.310363
# Gender(0=F|1=M)                                                                          -0.148881
# IPAQ_S                                                                                   -0.108919
# Category Encoded (0 = Non Fallers | 1 = Fallers)                                          1.000000
#
# [47 rows x 47 columns]

# %%
# let's make our correlation matrix a little prettier
corr_matrix = df.corr()
fig, ax = plt.subplots(figsize=(30, 20))
ax = sns.heatmap(corr_matrix,
                 annot=True,
                 linewidths=0.5,
                 fmt=".2f",
                 cmap="YlGnBu")

# %% [markdown]
# Let's see our new variables.

# %% [markdown]
# ## 6. Experimentation LR

# %%
#Target & features
# Feature 
X = df.drop("Category Encoded (0 = Non Fallers | 1 = Fallers)", axis=1)
X = X.values#MinMaxScaler().fit(X).transform(X)#
# Target variable
y = df["Category Encoded (0 = Non Fallers | 1 = Fallers)"].values


# Initial TT split 
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=1,stratify=y)

# cv
cv = RepeatedKFold(n_splits=10, n_repeats=5)#, random_state=1)

# %%
# # Optimize categorical HP with GridSearch 

# warnings.filterwarnings('ignore')
# # parameter grid
# parameters = {
#     'kernel' : ['linear','poly', 'rbf', 'sigmoid'],#, 'precomputed'], 
#     'gamma'  : ['scale', 'auto'],
#     'shrinking'    : [True, False],
#     'probability': [True, False],
#     'verbose': [True, False],
#     'class_weight':['balanced', None],
#     'decision_function_shape': ['ovo', 'ovr'],
#     'break_ties': [True, False],
#     # 'n_jobs' : [-1, None]
# }
# svm = SVC()
# clf = GridSearchCV(svm,                    # model
#                    param_grid = parameters,   # hyperparameters
#                    scoring='accuracy',        # metric for scoring
#                    cv=cv)                     # number of folds
# # scoring='roc_auc',
# clf.fit(X_train,y_train)
# print("Tuned Hyperparameters :", clf.best_params_)
# print("Accuracy :",clf.best_score_)

# %%
# #  Optimize continuous HP Validation curve using CV HP categorical Parameter

# ### SAME
# # Unscaled param: {'break_ties': True, 'class_weight': 'balanced', 
# 'decision_function_shape': 'ovr', 'gamma': 'scale', 'kernel': 'linear', 
# 'probability': True, 'shrinking': True, 'verbose': True}
# ### SAME





# Parameter_of_interest_ = 'degree'
# # Setting the range for the parameter
# # parameter_range = np.arange(0, 201, 10)
# parameter_range_ = [i for i in range(10)]
 
# # # Calculate accuracy on training and test set using the gamma parameter with 5 times 10-fold cross validation
# train_score_, test_score_ = validation_curve(SVC(break_ties= True, class_weight = 'balanced',
# decision_function_shape= 'ovr', gamma= 'scale', kernel='linear', probability=True,
# shrinking = True, verbose = True), X, y, #'random_state': None
#                                        param_name = Parameter_of_interest_, param_range = parameter_range_, cv= cv,
#                                        scoring = "accuracy")
 
# # Calculating mean and standard deviation of training score
# mean_train_score_ = np.mean(train_score_, axis = 1)
# std_train_score_ = np.std(train_score_, axis = 1)
 
# # Calculating mean and standard deviation of testing score
# mean_test_score_ = np.mean(test_score_, axis = 1)
# std_test_score_ = np.std(test_score_, axis = 1)
 
# # Plot mean accuracy scores for training and testing scores
# plt.plot(parameter_range_, mean_train_score_,
#      label = "Training Score", color = 'b')
# plt.plot(parameter_range_, mean_test_score_,
#    label = "Cross Validation Score", color = 'g')
 
# # Creating the plot
# plt.title("Validation Curve with Random Forest Classifier")
# plt.xlabel(Parameter_of_interest_+'_value')
# plt.ylabel("Accuracy")
# plt.tight_layout()
# plt.legend(loc = 'best')
# plt.show()
# print('to change: C (between 0 and 0.2) | to keep default: degree')

# %%
# # Add new Parameters and tune the randomness of LR 
# Parameter_of_interest_random_state = 'random_state'
# # Setting the range for the parameter
# parameter_rangerandom_state = np.arange(0, 101, 1)
 
# # # Calculate accuracy on training and test set using the gamma parameter with 5 times 10-fold cross validation
# train_scorerandom_state, test_scorerandom_state = validation_curve(LogisticRegression(class_weight = 'balanced', multi_class= 'auto',
# dual= False, fit_intercept= True, penalty= 'l1', solver= 'liblinear', C= 0.2, tol=0.0001, intercept_scaling=1, max_iter=100, verbose=0, n_jobs=-1), X, y,
#                                        param_name = Parameter_of_interest_random_state, param_range = parameter_rangerandom_state, cv= cv,
#                                        scoring = "accuracy")
 
# # Calculating mean and standard deviation of training score
# mean_train_scorerandom_state = np.mean(train_scorerandom_state, axis = 1)
# std_train_scorerandom_state = np.std(train_scorerandom_state, axis = 1)
 
# # Calculating mean and standard deviation of testing score
# mean_test_scorerandom_state = np.mean(test_scorerandom_state, axis = 1)
# std_test_scorerandom_state = np.std(test_scorerandom_state, axis = 1)
 
# # Plot mean accuracy scores for training and testing scores
# plt.plot(parameter_rangerandom_state, mean_train_scorerandom_state,
#      label = "Training Score", color = 'b')
# plt.plot(parameter_rangerandom_state, mean_test_scorerandom_state,
#    label = "Cross Validation Score", color = 'g')
 
# # Creating the plot
# plt.title("Validation Curve with Logistic Regression Classifier")
# plt.xlabel(Parameter_of_interest_random_state+'_value')
# plt.ylabel("Accuracy")
# plt.tight_layout()
# plt.legend(loc = 'best')
# plt.show()
# print('Best', Parameter_of_interest_random_state+'_value is 37')

# %%
# #Plot loss with final HP 
SVM_Model = SVC(break_ties= True, class_weight = 'balanced',
decision_function_shape= 'ovr', gamma= 'scale', kernel='linear', probability=True,
shrinking = True, verbose = True, C=.015)
plot_learning_curves(X_train, y_train, X_test, y_test, SVM_Model)
plt.show()
# Out:
# [LibSVM].*
# optimization finished, #iter = 39
# obj = -0.134280, rho = 16.944940
# nSV = 13, nBSV = 9
# Total nSV = 13
# *.*
# optimization finished, #iter = 25
# obj = -0.077403, rho = 21.679157
# nSV = 9, nBSV = 4
# Total nSV = 9
# *
# optimization finished, #iter = 12
# obj = -0.083765, rho = 14.670522
# nSV = 9, nBSV = 5
# Total nSV = 9
# *.*
# optimization finished, #iter = 33
# obj = -0.072333, rho = 22.719217
# nSV = 9, nBSV = 5
# Total nSV = 9
# .
# Warning: using -h 0 may be faster
# *
# optimization finished, #iter = 27
# obj = -0.119310, rho = 11.751815
# nSV = 11, nBSV = 9
# Total nSV = 11
# *
# optimization finished, #iter = 28
# obj = -0.134280, rho = -16.943729
# nSV = 13, nBSV = 9
# Total nSV = 13
# [LibSVM].*...*..*
# optimization finished, #iter = 295
# obj = -0.214279, rho = 9.075882
# nSV = 21, nBSV = 14
# Total nSV = 21
# .*
# optimization finished, #iter = 64
# obj = -0.206777, rho = -2.352681
# nSV = 20, nBSV = 16
# Total nSV = 20
# *.*
# optimization finished, #iter = 55
# obj = -0.179281, rho = 2.519591
# nSV = 17, nBSV = 13
# Total nSV = 17
# *
# optimization finished, #iter = 41
# obj = -0.209421, rho = -6.899972
# nSV = 19, nBSV = 14
# Total nSV = 19
# *
# optimization finished, #iter = 44
# obj = -0.199624, rho = -4.352486
# nSV = 18, nBSV = 14
# Total nSV = 18
# *
# optimization finished, #iter = 46
# obj = -0.260653, rho = -5.525863
# nSV = 23, nBSV = 20
# Total nSV = 23
# [LibSVM].....*....*
# optimization finished, #iter = 698
# obj = -0.384266, rho = 16.087780
# nSV = 34, nBSV = 26
# Total nSV = 34
# ..*.......*
# optimization finished, #iter = 687
# obj = -0.495903, rho = 12.065539
# nSV = 40, nBSV = 34
# Total nSV = 40
# ..*.*
# optimization finished, #iter = 239
# obj = -0.400191, rho = 15.558562
# nSV = 34, nBSV = 27
# Total nSV = 34
# .*.*
# optimization finished, #iter = 145
# obj = -0.246053, rho = -2.400052
# nSV = 26, nBSV = 20
# Total nSV = 26
# ..*.*...*
# optimization finished, #iter = 434
# obj = -0.480654, rho = 13.947194
# nSV = 39, nBSV = 33
# Total nSV = 39
# ...*.
# Warning: using -h 0 may be faster
# *.*.......*
# optimization finished, #iter = 1096
# obj = -0.543068, rho = -13.924006
# nSV = 44, nBSV = 38
# Total nSV = 44
# [LibSVM]....*...*
# optimization finished, #iter = 727
# obj = -0.568304, rho = 13.326260
# nSV = 47, nBSV = 39
# Total nSV = 47
# ..*.*
# optimization finished, #iter = 319
# obj = -0.512644, rho = 11.060329
# nSV = 43, nBSV = 35
# Total nSV = 43
# ..*.*.*
# optimization finished, #iter = 407
# obj = -0.434232, rho = 14.202764
# nSV = 39, nBSV = 32
# Total nSV = 39
# *.*
# optimization finished, #iter = 94
# obj = -0.344467, rho = 11.530064
# nSV = 31, nBSV = 24
# Total nSV = 31
# .
# Warning: using -h 0 may be faster
# *.*
# optimization finished, #iter = 238
# obj = -0.528784, rho = 15.387694
# nSV = 44, nBSV = 39
# Total nSV = 44
# .....*..............*.*.*
# optimization finished, #iter = 2496
# obj = -0.629927, rho = -12.968154
# nSV = 52, nBSV = 48
# Total nSV = 52
# [LibSVM].*
# optimization finished, #iter = 139
# obj = -0.566753, rho = 6.996611
# nSV = 48, nBSV = 42
# Total nSV = 48
# .
# Warning: using -h 0 may be faster
# *
# optimization finished, #iter = 142
# obj = -0.649514, rho = 19.547825
# nSV = 54, nBSV = 48
# Total nSV = 54
# ...*...*
# optimization finished, #iter = 755
# obj = -0.677335, rho = 12.220932
# nSV = 56, nBSV = 48
# Total nSV = 56
# .*
# optimization finished, #iter = 196
# obj = -0.723479, rho = 13.899964
# nSV = 59, nBSV = 54
# Total nSV = 59
# ..*
# optimization finished, #iter = 314
# obj = -0.592696, rho = 15.852076
# nSV = 51, nBSV = 43
# Total nSV = 51
# ...*
# optimization finished, #iter = 477
# obj = -0.817337, rho = -11.398572
# nSV = 69, nBSV = 63
# Total nSV = 69
# [LibSVM]...*.*
# optimization finished, #iter = 611
# obj = -0.828935, rho = 8.384503
# nSV = 68, nBSV = 57
# Total nSV = 68
# ..*
# optimization finished, #iter = 336
# obj = -0.739901, rho = 8.947405
# nSV = 61, nBSV = 52
# Total nSV = 61
# ...*.*...*
# optimization finished, #iter = 1019
# obj = -0.763349, rho = 0.605865
# nSV = 62, nBSV = 55
# Total nSV = 62
# ..
# Warning: using -h 0 may be faster
# *.....*
# optimization finished, #iter = 1059
# obj = -0.901174, rho = 9.327967
# nSV = 77, nBSV = 69
# Total nSV = 77
# ..*...*
# optimization finished, #iter = 724
# obj = -0.886132, rho = -0.127844
# nSV = 73, nBSV = 64
# Total nSV = 73
# ..
# Warning: using -h 0 may be faster
# *.*
# optimization finished, #iter = 610
# obj = -1.016490, rho = -4.899858
# nSV = 85, nBSV = 79
# Total nSV = 85
# [LibSVM]...*.*
# optimization finished, #iter = 703
# obj = -0.946978, rho = 2.865680
# nSV = 82, nBSV = 73
# Total nSV = 82
# ........*.
# Warning: using -h 0 may be faster
# *.....*
# optimization finished, #iter = 2376
# obj = -0.864461, rho = -2.763703
# nSV = 75, nBSV = 70
# Total nSV = 75
# ......*....*
# optimization finished, #iter = 1746
# obj = -0.962392, rho = 0.037465
# nSV = 80, nBSV = 68
# Total nSV = 80
# ..
# Warning: using -h 0 may be faster
# *
# optimization finished, #iter = 443
# obj = -0.862282, rho = 1.067600
# nSV = 73, nBSV = 65
# Total nSV = 73
# .....*.*
# optimization finished, #iter = 1080
# obj = -0.947797, rho = -2.732181
# nSV = 81, nBSV = 70
# Total nSV = 81
# .......*
# optimization finished, #iter = 1553
# obj = -1.105150, rho = 1.213427
# nSV = 99, nBSV = 87
# Total nSV = 99
# [LibSVM]...
# Warning: using -h 0 may be faster
# *.
# Warning: using -h 0 may be faster
# *...*..*
# optimization finished, #iter = 1579
# obj = -1.053172, rho = -3.791169
# nSV = 93, nBSV = 83
# Total nSV = 93
# ....*
# optimization finished, #iter = 838
# obj = -1.179625, rho = -1.610699
# nSV = 103, nBSV = 90
# Total nSV = 103
# ...*...........*..*
# optimization finished, #iter = 3173
# obj = -1.144024, rho = 6.341665
# nSV = 98, nBSV = 89
# Total nSV = 98
# ..
# Warning: using -h 0 may be faster
# **.*
# optimization finished, #iter = 646
# obj = -1.136290, rho = -3.034686
# nSV = 101, nBSV = 90
# Total nSV = 101
# .........*.
# Warning: using -h 0 may be faster
# *
# optimization finished, #iter = 1907
# obj = -1.216866, rho = -1.019765
# nSV = 107, nBSV = 98
# Total nSV = 107
# ...
# Warning: using -h 0 may be faster
# *
# optimization finished, #iter = 877
# obj = -1.382170, rho = 2.896745
# nSV = 126, nBSV = 114
# Total nSV = 126
# [LibSVM]....*........*
# optimization finished, #iter = 2607
# obj = -1.163845, rho = -3.212102
# nSV = 107, nBSV = 96
# Total nSV = 107
# .....*..*.
# Warning: using -h 0 may be faster
# *
# optimization finished, #iter = 1815
# obj = -1.298926, rho = -1.355915
# nSV = 117, nBSV = 107
# Total nSV = 117
# ....*..*
# optimization finished, #iter = 1325
# obj = -1.000485, rho = -1.738429
# nSV = 87, nBSV = 75
# Total nSV = 87
# .....*...*
# optimization finished, #iter = 1829
# obj = -1.313847, rho = -2.114146
# nSV = 118, nBSV = 109
# Total nSV = 118
# ...
# Warning: using -h 0 may be faster
# *.
# Warning: using -h 0 may be faster
# *
# optimization finished, #iter = 801
# obj = -1.331356, rho = -2.339978
# nSV = 120, nBSV = 112
# Total nSV = 120
# ...*........*
# optimization finished, #iter = 3044
# obj = -1.460126, rho = 3.073053
# nSV = 137, nBSV = 129
# Total nSV = 137
# [LibSVM]...
# Warning: using -h 0 may be faster
# *.*
# optimization finished, #iter = 968
# obj = -1.340739, rho = -5.038127
# nSV = 121, nBSV = 110
# Total nSV = 121
# ........*.*
# optimization finished, #iter = 2116
# obj = -1.433350, rho = -4.948965
# nSV = 135, nBSV = 123
# Total nSV = 135
# ....*..*...*
# optimization finished, #iter = 2111
# obj = -1.430576, rho = -1.982548
# nSV = 133, nBSV = 124
# Total nSV = 133
# ..
# Warning: using -h 0 may be faster
# *
# optimization finished, #iter = 657
# obj = -1.247361, rho = -5.621360
# nSV = 117, nBSV = 105
# Total nSV = 117
# ...
# Warning: using -h 0 may be faster
# *...
# Warning: using -h 0 may be faster
# *
# optimization finished, #iter = 1357
# obj = -1.387318, rho = 0.147563
# nSV = 130, nBSV = 116
# Total nSV = 130
# ...*.*
# optimization finished, #iter = 1278
# obj = -1.587986, rho = 5.263402
# nSV = 157, nBSV = 141
# Total nSV = 157

# %%
# Parameter_of_interest_ = 'C'
# # Setting the range for the parameter
# # parameter_range = np.arange(0, 201, 10)
# parameter_range_ = [i*10**(-3) for i in range(100)]
 
# # # Calculate accuracy on training and test set using the gamma parameter with 5 times 10-fold cross validation
# train_score_, test_score_ = validation_curve(SVC(break_ties= True, class_weight = 'balanced',
# decision_function_shape= 'ovr', gamma= 'scale', kernel='linear', probability=True,
# shrinking = True, verbose = True), X, y, #'random_state': None
#                                        param_name = Parameter_of_interest_, param_range = parameter_range_, cv= cv,
#                                        scoring = "accuracy")
 
# # Calculating mean and standard deviation of training score
# mean_train_score_ = np.mean(train_score_, axis = 1)
# std_train_score_ = np.std(train_score_, axis = 1)
 
# # Calculating mean and standard deviation of testing score
# mean_test_score_ = np.mean(test_score_, axis = 1)
# std_test_score_ = np.std(test_score_, axis = 1)
 
# # Plot mean accuracy scores for training and testing scores
# plt.plot(parameter_range_, mean_train_score_,
#      label = "Training Score", color = 'b')
# plt.plot(parameter_range_, mean_test_score_,
#    label = "Cross Validation Score", color = 'g')
 
# # Creating the plot
# plt.title("Validation Curve with Random Forest Classifier")
# plt.xlabel(Parameter_of_interest_+'_value')
# plt.ylabel("Accuracy")
# plt.tight_layout()
# plt.legend(loc = 'best')
# plt.show()

# %%
# Plot Accuracy Curve
plot_learning_curves(X_train, y_train, X_test, y_test, SVM_Model, scoring='accuracy')
plt.show()
# Out:
# [LibSVM].*
# optimization finished, #iter = 41
# obj = -0.081497, rho = 33.012511
# nSV = 9, nBSV = 5
# Total nSV = 9
# [LibSVM]..*
# optimization finished, #iter = 62
# obj = -0.117950, rho = 15.956280
# nSV = 13, nBSV = 8
# Total nSV = 13
# .*.*
# optimization finished, #iter = 48
# obj = -0.082646, rho = 17.725619
# nSV = 10, nBSV = 5
# Total nSV = 10
# .*
# optimization finished, #iter = 34
# obj = -0.120760, rho = 13.287420
# nSV = 11, nBSV = 8
# Total nSV = 11
# .*.*
# optimization finished, #iter = 47
# obj = -0.097372, rho = 0.668805
# nSV = 11, nBSV = 7
# Total nSV = 11
# *
# optimization finished, #iter = 28
# obj = -0.134280, rho = -16.943729
# nSV = 13, nBSV = 9
# Total nSV = 13
# ..*
# optimization finished, #iter = 139
# obj = -0.229395, rho = 2.685429
# nSV = 21, nBSV = 16
# Total nSV = 21
# .*...*
# optimization finished, #iter = 187
# obj = -0.165325, rho = -6.064726
# nSV = 17, nBSV = 12
# Total nSV = 17
# .*
# optimization finished, #iter = 67
# obj = -0.228925, rho = 0.829119
# nSV = 21, nBSV = 17
# Total nSV = 21
# *.*
# optimization finished, #iter = 50
# obj = -0.206867, rho = 7.552942
# nSV = 19, nBSV = 15
# Total nSV = 19
# *
# optimization finished, #iter = 44
# obj = -0.208596, rho = 5.858126
# nSV = 18, nBSV = 15
# Total nSV = 18
# *
# optimization finished, #iter = 46
# obj = -0.260653, rho = -5.525863
# nSV = 23, nBSV = 20
# Total nSV = 23
# [LibSVM]..*..*
# optimization finished, #iter = 317
# obj = -0.493533, rho = 11.356954
# nSV = 39, nBSV = 32
# Total nSV = 39
# ...*.*
# optimization finished, #iter = 299
# obj = -0.361488, rho = 17.174171
# nSV = 31, nBSV = 25
# Total nSV = 31
# *
# optimization finished, #iter = 50
# obj = -0.342951, rho = 10.273635
# nSV = 29, nBSV = 26
# Total nSV = 29
# .
# Warning: using -h 0 may be faster
# *.*
# optimization finished, #iter = 200
# obj = -0.405499, rho = 1.639381
# nSV = 34, nBSV = 29
# Total nSV = 34
# ...*....*
# optimization finished, #iter = 502
# obj = -0.427336, rho = 11.491386
# nSV = 35, nBSV = 29
# Total nSV = 35
# ...*.
# Warning: using -h 0 may be faster
# *.*.......*
# optimization finished, #iter = 1096
# obj = -0.543068, rho = -13.924006
# nSV = 44, nBSV = 38
# Total nSV = 44
# [LibSVM]..*.........................*
# optimization finished, #iter = 2601
# obj = -0.528507, rho = 13.115189
# nSV = 44, nBSV = 35
# Total nSV = 44
# ..*
# optimization finished, #iter = 232
# obj = -0.506798, rho = 14.421739
# nSV = 43, nBSV = 37
# Total nSV = 43
# *.*
# optimization finished, #iter = 105
# obj = -0.355010, rho = 8.412563
# nSV = 34, nBSV = 27
# Total nSV = 34
# ..*.*
# optimization finished, #iter = 285
# obj = -0.545588, rho = 14.125246
# nSV = 44, nBSV = 37
# Total nSV = 44
# .*
# optimization finished, #iter = 180
# obj = -0.489958, rho = 18.732837
# nSV = 40, nBSV = 34
# Total nSV = 40
# .....*..............*.*.*
# optimization finished, #iter = 2496
# obj = -0.629927, rho = -12.968154
# nSV = 52, nBSV = 48
# Total nSV = 52
# [LibSVM]..*
# optimization finished, #iter = 302
# obj = -0.655495, rho = 15.685134
# nSV = 53, nBSV = 46
# Total nSV = 53
# .
# Warning: using -h 0 may be faster
# *.*
# optimization finished, #iter = 247
# obj = -0.662263, rho = 15.533934
# nSV = 54, nBSV = 49
# Total nSV = 54
# *.*
# optimization finished, #iter = 134
# obj = -0.587748, rho = 1.218686
# nSV = 49, nBSV = 41
# Total nSV = 49
# ..
# Warning: using -h 0 may be faster
# *.
# Warning: using -h 0 may be faster
# *.*
# optimization finished, #iter = 472
# obj = -0.623535, rho = 15.417719
# nSV = 52, nBSV = 46
# Total nSV = 52
# ...*...*
# optimization finished, #iter = 717
# obj = -0.708934, rho = 12.377678
# nSV = 57, nBSV = 48
# Total nSV = 57
# ...*
# optimization finished, #iter = 477
# obj = -0.817337, rho = -11.398572
# nSV = 69, nBSV = 63
# Total nSV = 69
# [LibSVM]..*.*
# optimization finished, #iter = 517
# obj = -0.841213, rho = 6.167577
# nSV = 69, nBSV = 60
# Total nSV = 69
# ..*
# optimization finished, #iter = 313
# obj = -0.759987, rho = 2.153704
# nSV = 62, nBSV = 53
# Total nSV = 62
# ...*..*...*
# optimization finished, #iter = 992
# obj = -0.811537, rho = 1.187585
# nSV = 66, nBSV = 58
# Total nSV = 66
# ...*.*...*
# optimization finished, #iter = 981
# obj = -0.878238, rho = 12.298359
# nSV = 72, nBSV = 63
# Total nSV = 72
# ...*...*
# optimization finished, #iter = 957
# obj = -0.765186, rho = -1.476003
# nSV = 64, nBSV = 55
# Total nSV = 64
# ..
# Warning: using -h 0 may be faster
# *.*
# optimization finished, #iter = 610
# obj = -1.016490, rho = -4.899858
# nSV = 85, nBSV = 79
# Total nSV = 85
# [LibSVM].......*...*
# optimization finished, #iter = 1609
# obj = -0.826218, rho = -2.802446
# nSV = 72, nBSV = 65
# Total nSV = 72
# ..*
# optimization finished, #iter = 435
# obj = -0.926990, rho = 5.637913
# nSV = 81, nBSV = 72
# Total nSV = 81
# .
# Warning: using -h 0 may be faster
# *.*
# optimization finished, #iter = 348
# obj = -0.943940, rho = 5.570132
# nSV = 76, nBSV = 71
# Total nSV = 76
# ...*...................*.*
# optimization finished, #iter = 3695
# obj = -0.869681, rho = -2.874371
# nSV = 78, nBSV = 66
# Total nSV = 78
# .....*.*.*
# optimization finished, #iter = 1205
# obj = -1.011431, rho = -1.754563
# nSV = 87, nBSV = 77
# Total nSV = 87
# .......*
# optimization finished, #iter = 1553
# obj = -1.105150, rho = 1.213427
# nSV = 99, nBSV = 87
# Total nSV = 99
# [LibSVM]...*.........**..*
# optimization finished, #iter = 2596
# obj = -1.230513, rho = -2.090651
# nSV = 109, nBSV = 100
# Total nSV = 109
# ...
# Warning: using -h 0 may be faster
# *.....*
# optimization finished, #iter = 1570
# obj = -1.137111, rho = -2.429002
# nSV = 100, nBSV = 92
# Total nSV = 100
# ...
# Warning: using -h 0 may be faster
# *....*....*
# optimization finished, #iter = 2132
# obj = -1.176320, rho = -2.981488
# nSV = 101, nBSV = 92
# Total nSV = 101
# ....**.*
# optimization finished, #iter = 830
# obj = -1.157630, rho = 5.187886
# nSV = 101, nBSV = 92
# Total nSV = 101
# ....*.........*
# optimization finished, #iter = 2606
# obj = -1.061108, rho = -3.049033
# nSV = 94, nBSV = 84
# Total nSV = 94
# ...
# Warning: using -h 0 may be faster
# *
# optimization finished, #iter = 877
# obj = -1.382170, rho = 2.896745
# nSV = 126, nBSV = 114
# Total nSV = 126
# [LibSVM]..
# Warning: using -h 0 may be faster
# *
# optimization finished, #iter = 620
# obj = -1.221136, rho = -1.888525
# nSV = 108, nBSV = 96
# Total nSV = 108
# ...*.*.*.*
# optimization finished, #iter = 1213
# obj = -1.167213, rho = -0.914273
# nSV = 105, nBSV = 96
# Total nSV = 105
# ..
# Warning: using -h 0 may be faster
# *
# optimization finished, #iter = 497
# obj = -1.245171, rho = -0.915580
# nSV = 109, nBSV = 97
# Total nSV = 109
# .....*..*..*
# optimization finished, #iter = 1919
# obj = -1.230823, rho = -0.661045
# nSV = 106, nBSV = 93
# Total nSV = 106
# .....*.*
# optimization finished, #iter = 1331
# obj = -1.290835, rho = -0.888997
# nSV = 115, nBSV = 105
# Total nSV = 115
# ...*........*
# optimization finished, #iter = 3044
# obj = -1.460126, rho = 3.073053
# nSV = 137, nBSV = 129
# Total nSV = 137
# [LibSVM].........*...*.
# Warning: using -h 0 may be faster
# *......*
# optimization finished, #iter = 4485
# obj = -1.420253, rho = -2.918780
# nSV = 131, nBSV = 118
# Total nSV = 131
# ...*...........*...*
# optimization finished, #iter = 3921
# obj = -1.274443, rho = -6.358350
# nSV = 119, nBSV = 108
# Total nSV = 119
# ...*....*..*
# optimization finished, #iter = 2152
# obj = -1.390289, rho = -2.835580
# nSV = 127, nBSV = 118
# Total nSV = 127
# ...
# Warning: using -h 0 may be faster
# *....*.*
# optimization finished, #iter = 1876
# obj = -1.445844, rho = -2.832184
# nSV = 135, nBSV = 129
# Total nSV = 135
# ..
# Warning: using -h 0 may be faster
# *
# optimization finished, #iter = 632
# obj = -1.289520, rho = -2.244636
# nSV = 121, nBSV = 112
# Total nSV = 121
# ...*.*
# optimization finished, #iter = 1278
# obj = -1.587986, rho = 5.263402
# nSV = 157, nBSV = 141
# Total nSV = 157

# %%
# Model Performance
y_pred_test = SVM_Model.predict(X_test)
y_pred_train = SVM_Model.predict(X_train)

# Accuracy 
accuracy_test = accuracy_score(y_test,y_pred_test)
accuracy_train = accuracy_score(y_train,y_pred_train)

# Specificity
tn_test, fp_test, fn_test, tp_test = confusion_matrix(y_test,y_pred_test).ravel()
specificity_test = tn_test / (tn_test+fp_test)
tn_train, fp_train, fn_train, tp_train = confusion_matrix(y_train,y_pred_train).ravel()
specificity_train = tn_train / (tn_train+fp_train)

# Sensitivity 
tn_test, fp_test, fn_test, tp_test = confusion_matrix(y_test,y_pred_test).ravel()
sensitivity_test = tp_test / (tp_test+fn_test)
tn_train, fp_train, fn_train, tp_train = confusion_matrix(y_train,y_pred_train).ravel()
sensitivity_train = tp_train / (tp_train+fn_train)


# Precision
precision_test = precision_score(y_test,y_pred_test)
precision_train = precision_score(y_train,y_pred_train)

# NPV
tn_test, fp_test, fn_test, tp_test = confusion_matrix(y_test,y_pred_test).ravel()
NPV_test = tn_test / (tn_test+fp_test)
tn_train, fp_train, fn_train, tp_train = confusion_matrix(y_train,y_pred_train).ravel()
NPV_train = tn_train / (tn_train+fp_train)

# PPV
tn_test, fp_test, fn_test, tp_test = confusion_matrix(y_test,y_pred_test).ravel()
PPV_test = tp_test / (tp_test+fp_test)
tn_train, fp_train, fn_train, tp_train = confusion_matrix(y_train,y_pred_train).ravel()
PPV_train = tp_train / (tp_train+fp_train)

# AUROC 

auroc_test = roc_auc_score(y_test,y_pred_test)
auroc_train = roc_auc_score(y_train,y_pred_train)
def plot_roc_curve(true_y, y_prob):
    """
    plots the roc curve based of the probabilities
    """

    fpr, tpr, thresholds = roc_curve(true_y, y_prob)
    plt.plot(fpr, tpr)
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')

plot_roc_curve(y_test, y_pred_test)

# %%
score = pd.DataFrame(np.array([['Support Vector Machine', auroc_train, accuracy_train, specificity_train, sensitivity_train, precision_train
                                ,PPV_train, NPV_train, auroc_test, accuracy_test, specificity_test, sensitivity_test, precision_test
                                ,PPV_test, NPV_test]]))
score.columns = ['Label', 'auroc_train', 'accuracy_train', 'specificity_train', 'sensitivity_train (recall)', 'precision_train', 'PPV_train', 
'NPV_train', 'auroc_test', 'accuracy_test', 'specificity_test', 'sensitivity_test (recall)', 'precision_test', 'PPV_test', 'NPV_test']
score.to_csv('/Users/cyrilleetude/Desktop/BureauMacBookAirdeCyrille/Semester_Project_Cyrille_2022/MachineLEARNING/Models/SVM.csv')

# %%
SVM_Model.get_params()
# Out:
# {'C': 0.015,
#  'break_ties': True,
#  'cache_size': 200,
#  'class_weight': 'balanced',
#  'coef0': 0.0,
#  'decision_function_shape': 'ovr',
#  'degree': 3,
#  'gamma': 'scale',
#  'kernel': 'linear',
#  'max_iter': -1,
#  'probability': True,
#  'random_state': None,
#  'shrinking': True,
#  'tol': 0.001,
#  'verbose': True}

# %%
# get importance
importance = np.abs(SVM_Model.coef_[0])
features_names = list(df.drop("Category Encoded (0 = Non Fallers | 1 = Fallers)", axis=1).columns)
id = -1
# summarize feature importance
for i,v in zip(features_names, list(importance)):
    id=id+1
    print("Feature:", id, i, "Importance Score", v)
# plot feature importance
f = plt.figure()
f.set_figwidth(40)
f.set_figheight(30)

plt.bar([x for x in range(len(features_names))], importance)
default_x_ticks = range(len(features_names))
# plt.plot(default_x_ticks, y)
plt.xticks(default_x_ticks, [x for x in range(len(features_names))])
plt.show()
# Out:
# Feature: 0 Area (m^2)_fc Importance Score 0.0009134400887127646
# Feature: 1 Range AP (m)_fc Importance Score 0.00990309252241864
# Feature: 2 Range ML (m)_fc Importance Score 0.016788693844782036
# Feature: 3 Sway Length AP (m)_fc Importance Score 0.07689003764749998
# Feature: 4 Sway Length ML (m)_fc Importance Score 0.07449780228694823
# Feature: 5 Mean Velocity AP (m/s)_fc Importance Score 0.002563001254916668
# Feature: 6 Mean Velocity ML (m/s)_fc Importance Score 0.002483260076231594
# Feature: 7 RMS Acc AP (g)_fc Importance Score 0.002038421874050472
# Feature: 8 RMS Acc ML (g)_fc Importance Score 0.0018309745063321602
# Feature: 9 Area (m^2)_fo Importance Score 0.0007163860384216833
# Feature: 10 Range AP (m)_fo Importance Score 0.012904082238807495
# Feature: 11 Range ML (m)_fo Importance Score 0.011283252396701212
# Feature: 12 Sway Length AP (m)_fo Importance Score 0.10446472446871655
# Feature: 13 Sway Length ML (m)_fo Importance Score 0.05902892520563335
# Feature: 14 Mean Velocity AP (m/s)_fo Importance Score 0.003482157482290557
# Feature: 15 Mean Velocity ML (m/s)_fo Importance Score 0.0019676308401877654
# Feature: 16 RMS Acc AP (g)_fo Importance Score 0.0036537835074277438
# Feature: 17 RMS Acc ML (g)_fo Importance Score 0.0018101836965135941
# Feature: 18 Area (m^2)_gc Importance Score 6.161742134284512e-06
# Feature: 19 Range AP (m)_gc Importance Score 0.003759703560407398
# Feature: 20 Range ML (m)_gc Importance Score 0.0004449747185290809
# Feature: 21 Sway Length AP (m)_gc Importance Score 0.034866857779156595
# Feature: 22 Sway Length ML (m)_gc Importance Score 0.003819423416751179
# Feature: 23 Mean Velocity AP (m/s)_gc Importance Score 0.0011622285926385515
# Feature: 24 Mean Velocity ML (m/s)_gc Importance Score 0.00012731411389169225
# Feature: 25 RMS Acc AP (g)_gc Importance Score 0.002377569405289887
# Feature: 26 RMS Acc ML (g)_gc Importance Score 0.000481159531550821
# Feature: 27 Area (m^2)_go Importance Score 4.626678540332605e-05
# Feature: 28 Range AP (m)_go Importance Score 0.0019753293408441056
# Feature: 29 Range ML (m)_go Importance Score 0.0012140375709600007
# Feature: 30 Sway Length AP (m)_go Importance Score 0.02892210449605584
# Feature: 31 Sway Length ML (m)_go Importance Score 0.019806057736466223
# Feature: 32 Mean Velocity AP (m/s)_go Importance Score 0.0009640701498685216
# Feature: 33 Mean Velocity ML (m/s)_go Importance Score 0.0006602019245488686
# Feature: 34 RMS Acc AP (g)_go Importance Score 0.002260841105538142
# Feature: 35 RMS Acc ML (g)_go Importance Score 0.0017053071533609547
# Feature: 36 Age Importance Score 0.0200055304553291
# Feature: 37 Height Importance Score 0.04367951066938699
# Feature: 38 Weight Importance Score 0.029659698129173084
# Feature: 39 BMI Importance Score 0.0788165072550775
# Feature: 40 Falls12m Importance Score 1.150132437450074
# Feature: 41 Best_T Importance Score 0.009246719425964667
# Feature: 42 FES_T Importance Score 0.012681606016655356
# Feature: 43 AgeGroup(0=young|1=old) Importance Score 0.12389969180272173
# Feature: 44 Gender(0=F|1=M) Importance Score 0.07834885051626861
# Feature: 45 IPAQ_S Importance Score 0.20364896387297576

# %%
#Confusion matrix
from sklearn.metrics import ConfusionMatrixDisplay
cm = confusion_matrix(y_test, y_pred_test, labels=SVM_Model.classes_)
disp = ConfusionMatrixDisplay(confusion_matrix=cm,
display_labels=SVM_Model.classes_)
disp.plot()

plt.show()

# %%
# SAVE 

with open ('/Users/cyrilleetude/Desktop/Bureau - MacBook Air de Cyrille/Semester_Project_Cyrille_2022/MachineLEARNING/Models/Saved_Models/SVM_Model.pkl' , 'wb') as file:
    pickle.dump(SVM_Model, file)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /var/folders/rm/fz861vwx62vcc5c49ww298480000gq/T/ipykernel_5321/2173061641.py in <module>
#       1 # SAVE
#       2
# ----> 3 with open ('/Users/cyrilleetude/Desktop/Bureau - MacBook Air de Cyrille/Semester_Project_Cyrille_2022/MachineLEARNING/Models/Saved_Models/SVM_Model.pkl' , 'wb') as file:
#       4     pickle.dump(SVM_Model, file)
#
# FileNotFoundError: [Errno 2] No such file or directory: '/Users/cyrilleetude/Desktop/Bureau - MacBook Air de Cyrille/Semester_Project_Cyrille_2022/MachineLEARNING/Models/Saved_Models/SVM_Model.pkl'

# %%
with open('/Users/cyrilleetude/Desktop/Bureau - MacBook Air de Cyrille/Semester_Project_Cyrille_2022/MachineLEARNING/Models/Saved_Models/SVM_Model.pkl', 'rb') as file:  
    Loaded_Model = pickle.load(file)
