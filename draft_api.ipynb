# %%
# f = open("demofile3.txt", "w")
# f.write("Woops! I have deleted the content!")
# f.close()

# %%
# import plotly.graph_objects as go

# # Create random data with numpy
# import numpy as np
# np.random.seed(1)

# N = 100
# random_x = np.linspace(0, 1, N)
# random_y0 = np.random.randn(N) + 600
# random_y1 = np.random.randn(N)
# random_y2 = np.random.randn(N) - 600

# # Create traces
# fig = go.Figure()
# fig.add_trace(go.Scatter(x=random_x, y=random_y0,
#                     mode='lines',
#                     name='lines'))
# fig.add_trace(go.Scatter(x=random_x, y=random_y1,
#                     mode='lines+markers',
#                     name='lines+markers'))
# fig.add_trace(go.Scatter(x=random_x, y=random_y2,
#                     mode='markers', name='markers'))

# fig.show()
# fig.write_image("/Users/cyrilleetude/Downloads/graphic-main-2/example/assets/images/plot/fig1.png")

# %%
# import ast
# ast.literal_eval('[["caca",0,[0]], [0,0,1], [1,1,0]]')
# Out:
# [['caca', 0, [0]], [0, 0, 1], [1, 1, 0]]

# %%
# import pandas as pd

# #create dataframe
# df_marks = pd.DataFrame({'name': ['Somu', 'Kiku', 'Amol', 'Lini'],
#      'physics': [68, 74, 77, 78],
#      'chemistry': [84, 56, 73, 69],
#      'algebra': [78, 88, 82, 87]})

# #render dataframe as html
# html = df_marks.to_html()

# #write html to file
# text_file = open("index.html", "w")
# text_file.write(html)
# text_file.close()

# %%
# import aspose.words as aw

# doc = aw.Document("Input.pdf")
# doc.save("Output.html")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /var/folders/rm/fz861vwx62vcc5c49ww298480000gq/T/ipykernel_30859/3999198018.py in <module>
# ----> 1 import aspose.words as aw
#       2
#       3 doc = aw.Document("Input.pdf")
#       4 doc.save("Output.html")
#
# ModuleNotFoundError: No module named 'aspose'

# %%
import plotly.graph_objects as go
data = '2'
labels=['test']#, 'POI_ML Pre', 'POI_ML Post']
y=[float(data)]
colors = ['green']#,'green', 'red']
fig = go.Figure([go.Bar(x=labels, y=y, text=y,
            textposition='auto', marker_color=colors, width=0.3, opacity=0.6)])

for template in ["plotly_white"]:
    fig.update_layout(template=template, title_text='test')
fig.update_layout(showlegend=False)
fig.update_yaxes(title_text="Entered value", range= [0, float(data)*2])#, range= [46.421, 47.905])Probability of lateral Instability 0.002

fig.write_image("/Users/cyrilleetude/Desktop/BureauMacBookAirdeCyrille/FLUTTER_APP/my_first_app/assets/images/test.png")

# %%
str(float('45'))
# Out:
# '45.0'
